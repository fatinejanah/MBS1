# %%
#Importer lespackages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
#Lire la base de données
bd=pd.read_csv('/LoanExport.csv')
bd
# Out:
# <ipython-input-2-25b70e14eb7c>:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   bd=pd.read_csv('/LoanExport.csv')
#         CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  \
# 0                 0            199902                  N        202901  16974
# 1                 0            199902                  N        202901  19740
# 2                 0            199902                  N        202901  29940
# 3                 0            199902                  N        202901  31084
# 4                 0            199902                  N        202901  35644
# ...             ...               ...                ...           ...    ...
# 291446          839            199903                  N        202902  37964
# 291447          840            200210                  N        202904  35644
# 291448          840            200304                  N        202904  42044
# ...

# %%
#1. Data Cleaning:
#Identify
bd.isnull().sum()
# Out:
# CreditScore               0
# FirstPaymentDate          0
# FirstTimeHomebuyer        0
# MaturityDate              0
# MSA                       0
# MIP                       0
# Units                     0
# Occupancy                 0
# OCLTV                     0
# DTI                       0
# OrigUPB                   0
# LTV                       0
# OrigInterestRate          0
# Channel                   0
# PPM                       0
# ProductType               0
# PropertyState             0
# PropertyType              0
# PostalCode                0
# LoanSeqNum                0
# LoanPurpose               0
# OrigLoanTerm              0
# NumBorrowers              0
# SellerName            24994
# ServicerName              0
# EverDelinquent            0
# MonthsDelinquent          0
# MonthsInRepayment         0
# dtype: int64

# %%
#  handle missing values
bd.dropna(inplace=True)
bd
# Out:
#         CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  \
# 0                 0            199902                  N        202901  16974
# 1                 0            199902                  N        202901  19740
# 2                 0            199902                  N        202901  29940
# 3                 0            199902                  N        202901  31084
# 4                 0            199902                  N        202901  35644
# ...             ...               ...                ...           ...    ...
# 291446          839            199903                  N        202902  37964
# 291447          840            200210                  N        202904  35644
# 291448          840            200304                  N        202904  42044
# 291449          845            199904                  N        202903  37964
# 291450          849            199903                  N        202902  37964
#
# ...

# %%
# Remove duplicates
bd.drop_duplicates(inplace=True)
bd
# Out:
#         CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  \
# 0                 0            199902                  N        202901  16974
# 1                 0            199902                  N        202901  19740
# 2                 0            199902                  N        202901  29940
# 3                 0            199902                  N        202901  31084
# 4                 0            199902                  N        202901  35644
# ...             ...               ...                ...           ...    ...
# 291446          839            199903                  N        202902  37964
# 291447          840            200210                  N        202904  35644
# 291448          840            200304                  N        202904  42044
# 291449          845            199904                  N        202903  37964
# 291450          849            199903                  N        202902  37964
#
# ...

# %%
#Correct data types :
# Conversion des colonnes numériques
bd['CreditScore'] = bd['CreditScore'].astype('int')
bd['FirstPaymentDate'] = pd.to_datetime(bd['FirstPaymentDate'], format='%Y%m')
bd['MaturityDate'] = pd.to_datetime(bd['MaturityDate'], format='%Y%m')
bd['OrigUPB'] = bd['OrigUPB'].astype('int')
bd['OrigInterestRate'] = bd['OrigInterestRate'].astype('float')

# Conversion des colonnes catégorielles
bd['FirstTimeHomebuyer'] = bd['FirstTimeHomebuyer'].astype('category')
bd['Channel'] = bd['Channel'].astype('category')
bd['ProductType'] = bd['ProductType'].astype('category')
bd['PropertyState'] = bd['PropertyState'].astype('category')
bd['PropertyType'] = bd['PropertyType'].astype('category')
bd['SellerName'] = bd['SellerName'].astype('category')
bd['ServicerName'] = bd['ServicerName'].astype('category')
bd
# Out:
#         CreditScore FirstPaymentDate FirstTimeHomebuyer MaturityDate    MSA  \
# 0                 0       1999-02-01                  N   2029-01-01  16974
# 1                 0       1999-02-01                  N   2029-01-01  19740
# 2                 0       1999-02-01                  N   2029-01-01  29940
# 3                 0       1999-02-01                  N   2029-01-01  31084
# 4                 0       1999-02-01                  N   2029-01-01  35644
# ...             ...              ...                ...          ...    ...
# 291446          839       1999-03-01                  N   2029-02-01  37964
# 291447          840       2002-10-01                  N   2029-04-01  35644
# 291448          840       2003-04-01                  N   2029-04-01  42044
# 291449          845       1999-04-01                  N   2029-03-01  37964
# 291450          849       1999-03-01                  N   2029-02-01  37964
#
# ...

# %%
#2. Data Encoding:
le = LabelEncoder()
bd['FirstTimeHomebuyer'] = le.fit_transform(bd['FirstTimeHomebuyer'])
bd['Channel'] = le.fit_transform(bd['Channel'])
bd['ProductType'] = le.fit_transform(bd['ProductType'])
bd['PropertyState'] = le.fit_transform(bd['PropertyState'])
bd['PropertyType'] = le.fit_transform(bd['PropertyType'])
bd['SellerName'] = le.fit_transform(bd['SellerName'])
bd['ServicerName'] = le.fit_transform(bd['ServicerName'])
bd
# Out:
#         CreditScore FirstPaymentDate  FirstTimeHomebuyer MaturityDate    MSA  \
# 0                 0       1999-02-01                   0   2029-01-01  16974
# 1                 0       1999-02-01                   0   2029-01-01  19740
# 2                 0       1999-02-01                   0   2029-01-01  29940
# 3                 0       1999-02-01                   0   2029-01-01  31084
# 4                 0       1999-02-01                   0   2029-01-01  35644
# ...             ...              ...                 ...          ...    ...
# 291446          839       1999-03-01                   0   2029-02-01  37964
# 291447          840       2002-10-01                   0   2029-04-01  35644
# 291448          840       2003-04-01                   0   2029-04-01  42044
# 291449          845       1999-04-01                   0   2029-03-01  37964
# 291450          849       1999-03-01                   0   2029-02-01  37964
#
# ...

# %%
#3. Data Labelling:
# Séparer les caractéristiques et la cible
target = bd['EverDelinquent']
features = bd.drop('EverDelinquent', axis=1)
bd
# Out:
#         CreditScore FirstPaymentDate  FirstTimeHomebuyer MaturityDate    MSA  \
# 0                 0       1999-02-01                   0   2029-01-01  16974
# 1                 0       1999-02-01                   0   2029-01-01  19740
# 2                 0       1999-02-01                   0   2029-01-01  29940
# 3                 0       1999-02-01                   0   2029-01-01  31084
# 4                 0       1999-02-01                   0   2029-01-01  35644
# ...             ...              ...                 ...          ...    ...
# 291446          839       1999-03-01                   0   2029-02-01  37964
# 291447          840       2002-10-01                   0   2029-04-01  35644
# 291448          840       2003-04-01                   0   2029-04-01  42044
# 291449          845       1999-04-01                   0   2029-03-01  37964
# 291450          849       1999-03-01                   0   2029-02-01  37964
#
# ...

# %%
# Enregistrer les données prétraitées dans un nouveau fichier CSV
bd.to_csv('LoantExport.csv', index=False)

# %%
from google.colab import files

# Télécharger le fichier CSV
files.download('LoantExport.csv')
